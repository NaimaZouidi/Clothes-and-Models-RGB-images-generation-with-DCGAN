# %% [markdown]
# <a href="https://colab.research.google.com/github/NaimaZouidi/Clothes-and-models-RGB-images-generation-with-DCGAN/blob/main/Clothing_and_models_RGB_images_generation_with_DCGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clothing and models RGB images generation with Deep Convolutional Generative Adversarial Network (DCGAN)**
# This notebook uses the Deep Convolutional Generative Adversarial Network (DCGAN) architecture to generate RGB images of clothing and models. Please refer to
# the paper [Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks](https://arxiv.org/abs/1511.06434) for more information about DCGAN.
#
# DCGAN is a popular variant of Generative Adversarial Neural Networks (GANs), which has been outlined in 2016 by Meta. The DCGAN uses the Convolutional Neural Network (CNN) architechture to build the generator and the discriminator along side a couple of changes, in particular:
#
# 1.   Replacing any pooling layers with strided convolutions (discriminator) and fractional-strided convolutions (generator).
# 2.   Using batch normalization in both the generator and the discriminator.
# 3.   Removing fully connected hidden layers for deeper architectures.
# 4.   Using SeLU activation in generator for all layers except for the output, which uses tanh.
# 5.   Using LeakyReLU activation in the discriminator for all layer.

# %% [markdown]
# # Set-up enviroment

# %% [markdown]
# To run this colab you will need to import some python modules such as Tensorflow and opencv.

# %%
import tensorflow as tf
from tensorflow import keras
from IPython import display
from keras.preprocessing.image import img_to_array
import numpy as np
import os
import random
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Help-in functions

# %% [markdown]
# *This function will give the list of images in the Clothing & Models data set.*
#
# `imagesPath: is the path of the Clothing & Models dataset`

# %%
def getListOfImages(imagesPath):
    Images = [os.path.join(imagesPath, img) for img in os.listdir(imagesPath) if os.path.isfile(os.path.join(imagesPath, img))]
    return Images

# %% [markdown]
# *This function will display some random images from the Clothing & Models data set.*
#
# `imagesPath: is the path of the Clothing & Models dataset`
# ![testData.png](data:image/png;base64,...)

# %%
def display_images(imagesPath):
  listOfImages = getListOfImages(imagesPath) #Naima: get the list of images
  listOfImagesTemp = listOfImages.copy()
  random.shuffle(listOfImagesTemp) # Naima: use matplotlib to display 3 random images
  fig, axes = plt.subplots(1,8, figsize=(10, 10))
  axes.ravel()
  for i in range(8):
    image = cv2.imread(listOfImagesTemp[i])
    imageRgb = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    imageRgbResized = cv2.resize(imageRgb, (64, 64), interpolation=cv2.INTER_NEAREST) #Naima: resize images to 64x64x3 (the DCGAN output)
    axes[i].axis('off')
    axes[i].imshow(imageRgbResized)

# %% [markdown]
# This function will display a number of fake images (e.i, generated by the DCGAN).
#
# `images: is the list of fake images`
#
# `n_cols: is the number of fake images to be displayed`
# ![FakeData.png](data:image/png;base64,...)

# %%
def Display_fake_images(images, n_cols=None):
    display.clear_output(wait=False)
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1
    if images.shape[-1] == 1:
        images = np.squeeze(images, axis=-1)
    plt.figure(figsize=(10,10))
    for index, image in enumerate(images):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image)
        plt.axis('off')

# %% [markdown]
# This function will build the generator of the DCGAN as follow:
#
# ![DCGAN_Generator.jpg](data:image/jpeg;base64,...)
#
# `randomNormalDimensions: is the dimension of the normal distrubition, that will be feed into the generator`

# %%
def build_generator(randomNormalDimensions):
  generator = keras.models.Sequential([
    tf.keras.layers.Dense(8*8*512, activation='selu', input_shape=[randomNormalDimensions], name='generator_dense'),
    tf.keras.layers.Reshape((8, 8, 512), name='generator_reshape'),
    tf.keras.layers.BatchNormalization(name = 'generator_batch_normalization'),
    tf.keras.layers.Conv2DTranspose(256, kernel_size=4, strides=2, padding='SAME', activation='selu', name='generator_conv2dTranspose_1'),
    tf.keras.layers.BatchNormalization(name = 'generator_batch_normalization_2'),
    tf.keras.layers.Conv2DTranspose(128, kernel_size=4, strides=2, padding='SAME', activation='selu', name='generator_conv2dTranspose_2'),
    tf.keras.layers.BatchNormalization(name = 'generator_batch_normalization_3'),
    tf.keras.layers.Conv2DTranspose(64, kernel_size=4, strides=2, padding='SAME', activation='selu', name='generator_conv2dTranspose_3'),
    tf.keras.layers.BatchNormalization(name = 'generator_batch_normalization_4'),
    tf.keras.layers.Conv2DTranspose(3, kernel_size=4, strides=1, padding='SAME', activation='tanh', name='generator_conv2dTranspose_4'),
    ])
  return generator

# %% [markdown]
# This function will build the discriminator of the DCGAN as follow:![DCGAN_Discriminator.jpg](data:image/jpeg;base64,...)

# %%
def build_discriminator():
    discriminator = keras.models.Sequential([
      tf.keras.layers.Conv2D(64, kernel_size=4, strides=2, padding='SAME', input_shape = (64,64,3), name='discriminator_conv2d'),
      tf.keras.layers.LeakyReLU(alpha = 0.2, name='discriminator_leakyRelu'),
      tf.keras.layers.Dropout(0.4, name='discriminator_droupout'),
      tf.keras.layers.Conv2D(128, kernel_size=4, strides=2, padding='SAME', input_shape = (64,64,3), name='discriminator_conv2d_1'),
      tf.keras.layers.LeakyReLU(alpha = 0.2, name='discriminator_leakyRelu_1'),
      tf.keras.layers.Dropout(0.4, name='discriminator_droupout_1'),
      tf.keras.layers.Flatten(name='discriminator_flatten'),
      tf.keras.layers.Dense(1, activation = 'sigmoid', name='discriminator_dense')
    ])
    return discriminator

# %% [markdown]
# This function will train the DCGAN.
#
#
# `dcgan: is the DCGAN model`
#
#
# `randomNormalDimensions: is the dimension of the normal distrubition, that will be feed into the generator`
#
# `n_epochs: is the number of learning epochs`

# %%
def train_dcgan(dcgan, dataset, randomNormalDimensions, n_epochs=50):
    generator, discriminator = dcgan.layers
    for epoch in range(n_epochs):
        print("Epoch {}/{}".format(epoch + 1, n_epochs))
        for realImages in dataset:

            #Naima: 1st phase!
            #train discriminator to destiguish between fake and real images
            real_batch_size = realImages.shape[0]
            noise = tf.random.normal([real_batch_size, randomNormalDimensions])
            fakeImages = generator(noise)
            mixed_images = tf.concat([fakeImages, realImages], axis = 0)
            discriminatorLabels = tf.constant([[0.0]]*real_batch_size +
                                    [[1.0]] * real_batch_size)
            discriminator.trainable = True
            discriminatorLabels += 0.05 * tf.random.uniform(tf.shape(discriminatorLabels)) #Naima: use label smoothing to weaken the discriminator
            discriminator.train_on_batch(mixed_images, discriminatorLabels)
            #Naima: 2nd phase!
            #train generator to fool the discriminator
            noise = tf.random.normal([real_batch_size, randomNormalDimensions])
            generatorLabels = tf.constant([1.0]*real_batch_size)
            discriminator.trainable = False
            dcgan.train_on_batch(noise, generatorLabels)
        Display_fake_images(fakeImages, 8)
        plt.show()
    return fakeImages

# %% [markdown]
# # Download the Clothing & Models dataset

# %% [markdown]
# Fisrt we will download the [Clothing & Models](https://www.kaggle.com/datasets/dqmonn/zalando-store-crawl) data set from kaggle. This latter is a collection of 16k clothing pieces, scraped from the online store Zalando.com.
#
# P.S: Please refer to this [discusion](https://www.kaggle.com/discussions/general/74235) for more datails on how to download and use kaggle data sets within Google Colab.

# %%
# !pip install -q kaggle

# %%
if not os.path.exists('/root/.kaggle/') :  #Naima: you need to upload the kaggle.json to your google colab workspace before running this cell!
  # !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d dqmonn/zalando-store-crawl
# Out:
# Downloading zalando-store-crawl.zip to /content
# 100% 2.24G/2.24G [01:19<00:00, 32.8MB/s]
# 100% 2.24G/2.24G [01:19<00:00, 30.2MB/s]

# %%
# !unzip zalando-store-crawl.zip -d zalando
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00K-K11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00L-C11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00L-H11@7.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00L-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00M-G11@13.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00N-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00O-Q11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00P-N11@5.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00Q-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00U-A11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NAA21J00V-P11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NE221J007-Q11@1.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NE221J00C-A11@1.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NE221J00D-J11@2.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NE221J00D-Q11@2.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NE221J00D-Q12@2.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NE221J00E-A11@1.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NE221J00E-C11@1.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NE221J00E-Q11@1.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J05P-Q11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J066-A11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J066-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J066-G12@7.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J066-J13@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J066-J14@10.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J066-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J07U-Q11@1.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J084-C11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J084-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J086-E11@8.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J086-G11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J086-H11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J086-K11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J086-N11@16.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J087-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J088-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J088-H11@14.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J088-K11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J088-M11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J088-Q11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J089-H11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08A-C11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08B-G11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08B-K11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08D-A11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08D-Q11@6.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08E-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08F-H11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08G-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08H-A11@16.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08H-C11@14.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08H-Q11@12.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08I-C11@15.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08U-Q11@12.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08W-C11@12.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08W-N11@13.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08X-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08X-J11@4.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J08X-Q11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J090-C11@14.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J090-H11@9.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J090-Q11@14.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J092-A11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J092-J11@6.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J092-Q11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J09Z-Q11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J0A2-A11@2.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NI121J0AF-B11@1.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04L-A11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04O-B11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04Q-E11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04R-E11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04T-B11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04T-E11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04T-H11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04U-E11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04V-H11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J04X-C11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J050-A11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J051-M11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J055-K11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J058-E11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J058-G11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NL021J05B-H11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03D-C11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03D-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03E-A11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03F-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03F-J11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03F-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03G-E11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03G-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03H-G11@8.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03H-M11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03I-G11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03I-J11@10.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03I-M11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03I-Q11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03J-M11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03L-C11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03L-K11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03N-C11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03N-G11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03N-H11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03N-K11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03N-M11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03O-C11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03O-K11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03P-C11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03S-G11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03S-K11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03T-K11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03U-A11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM321J03V-K11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM521J00B-C11@14.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM521J00C-C11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NM521J00D-G11@13.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NN121J004-M11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NN121J005-Q11@4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NOB21E00P-K11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/NT521J002-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt-female/
G11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S00R-K12@19.2.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S00R-N11@16.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S00R-Q11@30.2.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S02G-A11@18.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S02G-C11@18.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S02G-G11@10.4.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S02G-K11@16.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S02G-Q11@18.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S055-E11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S05H-A11@11.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S05H-Q11@11.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S05U-E11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S05V-G11@16.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S05W-K11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S05X-C11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S05Y-C11@10.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S063-K11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S064-A11@12.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S064-Q11@15.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S065-Q11@14.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S069-Q11@14.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06A-C11@14.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06D-A11@15.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06E-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06H-H11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06I-C11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06J-Q11@15.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06N-C11@9.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06N-K11@11.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06O-K11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06O-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06P-Q11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06R-C11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06S-K11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06X-K11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S06Z-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S070-Q11@21.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S071-C11@14.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S073-A11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S075-H11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S076-K11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S077-A11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S078-Q11@11.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S079-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07A-A11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07C-A11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07D-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07G-M11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07H-K11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07H-Q11@11.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07J-Q11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07K-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07L-M11@14.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07O-Q11@12.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07P-G11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07X-K11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07Y-Q11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S07Z-Q11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S081-C11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S082-Q11@13.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S095-A11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122S095-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA15-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA1F-C11@10.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA1F-Q11@9.2.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA38-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA38-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA43-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA44-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA46-C11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4S-A11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4S-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4S-G11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4S-G12@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4S-G13@12.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4S-H11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4S-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4V-A11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA4V-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA51-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA6I-J11@11.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA76-A11@9.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA7D-N11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA7D-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA8X-N11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA9I-K11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA9Q-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA9U-A11@7.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA9U-Q11@5.2.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA9V-Q11@11.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA9X-E11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO122SA9X-K11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO422S007-K11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YO422S007-M11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G009-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G009-G11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G009-M11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G009-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00A-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00A-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00D-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00D-K11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00D-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00E-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00E-G11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00E-K11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00E-M11@10.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00E-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00F-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142G00F-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/YT142GA13-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/Z2122S003-Q11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/Z2122S004-B11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/Z2122S005-Q11@7.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S002-C11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S002-K11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S002-K12@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S002-Q11@10.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S004-C11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S005-C11@11.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S005-K11@11.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S005-N11@22.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S005-Q11@11.1.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/ZA822S006-N11@8.jpg
#   inflating: zalando/zalando/zalando/sweatshirt/sweatshirt.txt

# %% [markdown]
# # Train the DCGAN
# Now it's time to train the DCGAN to generate fake images of clothes & models.
#
# First you will need to create the training data set using the Clothes & models data set and display some random examples.
#
# For the sake of computational complexity, we will train the DCGAN to generate images of size 64x64.

# %%
train_images = tf.keras.utils.image_dataset_from_directory(
   "/content/zalando/zalando", label_mode=None, image_size=(64, 64), batch_size=32)
# Out:
# Found 32360 files belonging to 1 classes.

# %%
train_images = train_images.map(lambda x: (x - 127.5) / 127.5) #Naima: normalize the images pixels between [-1, 1]

# %%
display_images("/content/zalando/zalando/hoodies-female/")

# %%
randomNormalDimensions = 100

# %%
generator = build_generator(randomNormalDimensions)
discriminator = build_discriminator()
discriminator.compile(loss='bce', optimizer='sgd') #Naima: use SGD for the discriminator
discriminator.trainable = False
dcgan = keras.models.Sequential([generator, discriminator])
dcgan.compile(loss='bce', optimizer='adam') #Naima: use ADAM for the generator

# %%
epochs = 500 #you can increase the number of epochs for better results!!
fake_images = train_dcgan(dcgan, train_images, randomNormalDimensions, epochs)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 4/500

# %%
Display_fake_images(fake_images, 16)
plt.show()
